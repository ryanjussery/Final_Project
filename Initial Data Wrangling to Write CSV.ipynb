# %%
import pandas as pd
df = pd.read_excel('Data/Energy Data/Converted Invoices/FY 21/Camp Bullis Apr 21.xlsx')

# %%
df.head()
# Out:
#   Account number  Collective #        BP#       Customer Name1  \
# 0   300-0424-343  500-0012-000  105515018  US GOVT CAMP BULLIS
# 1   300-0424-351  500-0012-000  105515018  US GOVT CAMP BULLIS
# 2   300-0424-355  500-0012-000  105515018  US GOVT CAMP BULLIS
# 3   300-0424-358  500-0012-000  105515018  US GOVT CAMP BULLIS
# 4   300-0424-366  500-0012-000  105515018  US GOVT CAMP BULLIS
#
#    Customer Name2          Service Address1 Store No  Bill Date   Due Date  \
# 0             NaN       19540 FM 1535 #GSTA      NaN 2021-05-03 2021-06-02
# 1             NaN    5100 CAMP BULLIS RD #9      NaN 2021-05-03 2021-06-02
# 2             NaN    5100 CAMP BULLIS RD #1      NaN 2021-05-03 2021-06-02
# 3             NaN  5100 CAMP BULLIS RD #WEL      NaN 2021-05-03 2021-06-02
# 4             NaN       5257 CAMP BULLIS RD      NaN 2021-05-03 2021-06-02
#
#   Billing Period From  ... City Services  State & Local Sales Taxes  \
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#   Account number  Collective #        BP#       Customer Name1  \
# 0   300-0424-343  500-0012-000  105515018  US GOVT CAMP BULLIS
# 1   300-0424-351  500-0012-000  105515018  US GOVT CAMP BULLIS
# 2   300-0424-355  500-0012-000  105515018  US GOVT CAMP BULLIS
# 3   300-0424-358  500-0012-000  105515018  US GOVT CAMP BULLIS
# 4   300-0424-366  500-0012-000  105515018  US GOVT CAMP BULLIS
#
#    Customer Name2          Service Address1 Store No  Bill Date   Due Date  \
# 0             NaN       19540 FM 1535 #GSTA      NaN 2021-05-03 2021-06-02
# 1             NaN    5100 CAMP BULLIS RD #9      NaN 2021-05-03 2021-06-02
# 2             NaN    5100 CAMP BULLIS RD #1      NaN 2021-05-03 2021-06-02
# 3             NaN  5100 CAMP BULLIS RD #WEL      NaN 2021-05-03 2021-06-02
# 4             NaN       5257 CAMP BULLIS RD      NaN 2021-05-03 2021-06-02
#
#   Billing Period From Billing Period To  Elec Meter1 #  Elec Meter2 #  \
# ...

# %%
template = df[["Account number","Collective #" ]]

# %%
template
# Out:
#     Account number  Collective #
# 0     300-0424-343  500-0012-000
# 1     300-0424-351  500-0012-000
# 2     300-0424-355  500-0012-000
# 3     300-0424-358  500-0012-000
# 4     300-0424-366  500-0012-000
# ..             ...           ...
# 217   300-1583-762  500-0012-000
# 218   300-1587-677  500-0012-000
# 219   300-2897-491  500-0012-000
# 220   300-3906-374  500-0012-000
# 221   300-4261-435  500-0012-000
#
# [222 rows x 2 columns]
