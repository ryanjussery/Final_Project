# %%
## Import pandas and read file.
### Save dataframe with a name of

# %% [markdown]
# 1. Run every excel through code to select required columns.
# 2. Set data set as CampBullisFY19”Month”  Stack up pull data two lines below
# 3. Drop NA(True)
# 4. Stack data sets as CampBullisFY19Combined and CampBullisFY20Combined.
# 5. Group by “meter number”
# 6. Then “date descending”

# %%
import pandas as pd
CampBullisFY19 = pd.read_excel('Data/Energy Data/Converted Invoices/FY 20/FY 20.xlsx')

# %%
CampBullisFY19.head()
# Out:
#   Account number  Collective #        BP#       Customer Name1  \
# 0   300-0424-343  500-0012-000  105515018  US GOVT CAMP BULLIS
# 1   300-0424-351  500-0012-000  105515018  US GOVT CAMP BULLIS
# 2   300-0424-358  500-0012-000  105515018  US GOVT CAMP BULLIS
# 3   300-1401-926  500-0012-000  105515018  US GOVT CAMP BULLIS
# 4   300-1401-938  500-0012-000  105515018  US GOVT CAMP BULLIS
#
#    Customer Name2          Service Address1 Store No  Bill Date   Due Date  \
# 0             NaN       19540 FM 1535 #GSTA      NaN 2020-05-01 2020-06-01
# 1             NaN    5100 CAMP BULLIS RD #9      NaN 2020-05-01 2020-06-01
# 2             NaN  5100 CAMP BULLIS RD #WEL      NaN 2020-05-01 2020-06-01
# 3             NaN             887 CMPB-DUTY      NaN 2020-05-01 2020-06-01
# 4             NaN     888 CMPB-WILKERSON RD      NaN 2020-05-01 2020-06-01
#
#   Billing Period From  ... City Services  State & Local Sales Taxes  \
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
CampBullisFY19.head()
# Out:
#   Account number  Collective #        BP#       Customer Name1  \
# 0   300-0424-343  500-0012-000  105515018  US GOVT CAMP BULLIS
# 1   300-0424-351  500-0012-000  105515018  US GOVT CAMP BULLIS
# 2   300-0424-358  500-0012-000  105515018  US GOVT CAMP BULLIS
# 3   300-1401-926  500-0012-000  105515018  US GOVT CAMP BULLIS
# 4   300-1401-938  500-0012-000  105515018  US GOVT CAMP BULLIS
#
#    Customer Name2          Service Address1 Store No  Bill Date   Due Date  \
# 0             NaN       19540 FM 1535 #GSTA      NaN 2020-05-01 2020-06-01
# 1             NaN    5100 CAMP BULLIS RD #9      NaN 2020-05-01 2020-06-01
# 2             NaN  5100 CAMP BULLIS RD #WEL      NaN 2020-05-01 2020-06-01
# 3             NaN             887 CMPB-DUTY      NaN 2020-05-01 2020-06-01
# 4             NaN     888 CMPB-WILKERSON RD      NaN 2020-05-01 2020-06-01
#
#   Billing Period From Billing Period To  Elec Meter1 #  Elec Meter2 #  \
# ...

# %% [markdown]
# # Pull columns into new data frame
# ## Change Name for each month

# %%
FY19Trimmed = CampBullisFY19[["Account number","Collective #","Customer Name1",'Service Address1',"Billing Period From","Billing Period To",
               "Elec Meter1 #","Elec Rate1","Elec Days on Bill Current", "Elec Kwh Used Current", "Actual Demand KW","Billing Demand KW"
              ,"Current Electricity Charge", "Elec Reg Adj1","City Services","City Services", "State & Local Sales Taxes", 
              "Additional Products & Services Total", "Total Current Energy Charge"]]

# %%
FY19Trimmed
# Out:
#      Account number  Collective #       Customer Name1  \
# 0      300-0424-343  500-0012-000  US GOVT CAMP BULLIS
# 1      300-0424-351  500-0012-000  US GOVT CAMP BULLIS
# 2      300-0424-358  500-0012-000  US GOVT CAMP BULLIS
# 3      300-1401-926  500-0012-000  US GOVT CAMP BULLIS
# 4      300-1401-938  500-0012-000  US GOVT CAMP BULLIS
# ...             ...           ...                  ...
# 2653   300-4224-269  500-0012-000  US GOVT CAMP BULLIS
# 2654   300-4261-435  500-0012-000  US GOVT CAMP BULLIS
# 2655   300-4293-743  500-0012-000  US GOVT CAMP BULLIS
# 2656   300-4351-578  500-0012-000  US GOVT CAMP BULLIS
# 2657   300-4606-331  500-0012-000  US GOVT CAMP BULLIS
#
#                   Service Address1 Billing Period From Billing Period To  \
# 0              19540 FM 1535 #GSTA          2020-03-28        2020-04-29
# 1           5100 CAMP BULLIS RD #9          2020-03-28        2020-04-29
# 2         5100 CAMP BULLIS RD #WEL          2020-03-28        2020-04-29
# ...

# %%
FY19Trimmed.to_excel( "FY19Trimmed.xlsx", index=False, encoding='utf-8-sig')

# %%
import os
import glob
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 3487-8AFD
#
#  Directory of C:\Users\Default.DESKTOP-RCU2N8C\Documents\GitHub\Final_Project
#
# 09/20/2021  09:00 PM    <DIR>          .
# 09/20/2021  09:00 PM    <DIR>          ..
# 09/16/2021  07:31 PM                34 .gitignore
# 09/10/2021  02:55 PM    <DIR>          .ipynb_checkpoints
# 09/20/2021  08:50 PM    <DIR>          Data
# 09/16/2021  07:23 PM    <DIR>          Documents
# 09/20/2021  09:00 PM            55,266 Initial Data Wrangling to Write CSV.ipynb
# 08/24/2021  07:36 PM    <DIR>          Media
# 08/24/2021  07:36 PM    <DIR>          New folder (4)
# 08/24/2021  07:35 PM                53 README.md
#                3 File(s)         55,353 bytes
#                7 Dir(s)  51,859,968,000 bytes free

# %%
os.chdir("Data/Energy Data/Converted Invoices/FY 20")

# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 3487-8AFD
#
#  Directory of C:\Users\Default.DESKTOP-RCU2N8C\Documents\GitHub\Final_Project\Data\Energy Data\Converted Invoices\FY 20
#
# 09/20/2021  08:51 PM    <DIR>          .
# 09/20/2021  08:51 PM    <DIR>          ..
# 09/14/2021  10:04 AM            51,229 Camp Bullis Apr 20.xlsx
# 09/14/2021  10:21 AM            51,783 Camp Bullis Aug 20.xlsx
# 09/10/2021  02:59 PM            54,707 Camp Bullis Dec 19.xlsx
# 09/10/2021  02:03 PM            49,113 Camp Bullis Feb 20.xlsx
# 09/10/2021  02:03 PM            49,785 Camp Bullis Jan 20.xlsx
# 09/14/2021  10:18 AM            50,643 Camp Bullis Jul 20.xlsx
# 09/14/2021  10:08 AM            53,420 Camp Bullis Jun 20.xlsx
# 09/14/2021  10:02 AM            51,404 Camp Bullis Mar 20.xlsx
# 09/14/2021  10:06 AM            51,296 Camp Bullis May 20.xlsx
# 09/10/2021  02:03 PM            48,388 Camp Bullis Nov 19.xlsx
# 09/10/2021  02:03 PM            49,182 Camp Bullis Oct 19.xlsx
# ...

# %%
CampBullisFY20 = pd.read_excel('FY 20.xlsx')

# %%
CampBullisFY20
# Out:
#      Account number  Collective #        BP#       Customer Name1  \
# 0      300-0424-343  500-0012-000  105515018  US GOVT CAMP BULLIS
# 1      300-0424-351  500-0012-000  105515018  US GOVT CAMP BULLIS
# 2      300-0424-358  500-0012-000  105515018  US GOVT CAMP BULLIS
# 3      300-1401-926  500-0012-000  105515018  US GOVT CAMP BULLIS
# 4      300-1401-938  500-0012-000  105515018  US GOVT CAMP BULLIS
# ...             ...           ...        ...                  ...
# 2653   300-4224-269  500-0012-000  105515018  US GOVT CAMP BULLIS
# 2654   300-4261-435  500-0012-000  105515018  US GOVT CAMP BULLIS
# 2655   300-4293-743  500-0012-000  105515018  US GOVT CAMP BULLIS
# 2656   300-4351-578  500-0012-000  105515018  US GOVT CAMP BULLIS
# 2657   300-4606-331  500-0012-000  105515018  US GOVT CAMP BULLIS
#
#       Customer Name2              Service Address1 Store No  Bill Date  \
# 0                NaN           19540 FM 1535 #GSTA      NaN 2020-05-01
# ...

# %%
FY20Trimmed = CampBullisFY20[["Account number","Collective #","Customer Name1",'Service Address1',"Billing Period From","Billing Period To",
               "Elec Meter1 #","Elec Rate1","Elec Days on Bill Current", "Elec Kwh Used Current", "Actual Demand KW","Billing Demand KW"
              ,"Current Electricity Charge", "Elec Reg Adj1","City Services","City Services", "State & Local Sales Taxes", 
              "Additional Products & Services Total", "Total Current Energy Charge"]]

# %%
FY20Trimmed
# Out:
#      Account number  Collective #       Customer Name1  \
# 0      300-0424-343  500-0012-000  US GOVT CAMP BULLIS
# 1      300-0424-351  500-0012-000  US GOVT CAMP BULLIS
# 2      300-0424-358  500-0012-000  US GOVT CAMP BULLIS
# 3      300-1401-926  500-0012-000  US GOVT CAMP BULLIS
# 4      300-1401-938  500-0012-000  US GOVT CAMP BULLIS
# ...             ...           ...                  ...
# 2653   300-4224-269  500-0012-000  US GOVT CAMP BULLIS
# 2654   300-4261-435  500-0012-000  US GOVT CAMP BULLIS
# 2655   300-4293-743  500-0012-000  US GOVT CAMP BULLIS
# 2656   300-4351-578  500-0012-000  US GOVT CAMP BULLIS
# 2657   300-4606-331  500-0012-000  US GOVT CAMP BULLIS
#
#                   Service Address1 Billing Period From Billing Period To  \
# 0              19540 FM 1535 #GSTA          2020-03-28        2020-04-29
# 1           5100 CAMP BULLIS RD #9          2020-03-28        2020-04-29
# 2         5100 CAMP BULLIS RD #WEL          2020-03-28        2020-04-29
# ...

# %%
FY20Trimmed.to_excel( "FY20Trimmed.xlsx", index=False, encoding='utf-8-sig')
